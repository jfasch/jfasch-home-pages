# %% [markdown]
# # BlahBlah

# %%
i = 666

# %%
print(i)
# Out:
# 666

# %%
print(type(i))
# Out:
# <class 'int'>

# %%
j = 42

# %%
def f():
    print('hallo')

# %%
f()
# Out:
# hallo

# %%
print(type(f))
# Out:
# <class 'function'>

# %%
class Square:
    def __init__(self, kantenlaenge):
        self.kantenlaenge = kantenlaenge
    def area(self):
        return self.kantenlaenge ** 2

# %%
q = Square(10)
q.area()
# Out:
# 100

# %%
s = 'mississippi'
print(type(s))
# Out:
# <class 'str'>

# %%
s.count('ss')
# Out:
# 2

# %%
s.find('ss')
# Out:
# 2

# %% [markdown]
# ## Interactive

# %%
i = 0
summe = 0
while i < 100:
    summe += i
    i += 1
print(summe)
# Out:
# 4950

# %% [markdown]
# ## For Beginners

# %%
for element in range(0,5):
    print(element)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Not For Beginners?

# %%
i = 666

# %%
type(i)
# Out:
# int

# %%
i = ['eins', 1, 1.0]

# %%
type(i)
# Out:
# list

# %%
a = 42
b = '666'

# %%
try:
    if a < b:
        print('jo eh')
except Exception as e:
    print(type(e), e)
# Out:
# <class 'TypeError'> '<' not supported between instances of 'int' and 'str'

# %% [markdown]
# # Strings, 1st Explanation

# %%
s = 'abc'
s
# Out:
# 'abc'

# %%
s = "abc"
s
# Out:
# 'abc'

# %%
s = 'ab"cd'
s
# Out:
# 'ab"cd'

# %%
s = "ab'cd"
s
# Out:
# "ab'cd"

# %%
print(s)
# Out:
# ab'cd

# %%
try:
    s = 'abc
except Exception as e:
    print(type(e), e)
# Out:
#   File "/tmp/ipykernel_12024/2437887948.py", line 2
#     s = 'abc
#             ^
# SyntaxError: EOL while scanning string literal
