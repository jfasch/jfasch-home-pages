# %% [markdown]
# # Python Basics (2023-05-15 - 2023-05-17)

# %%
code = '[1,2,3]'

# %%
type(code)
# Out:
# str

# %% [markdown]
# blah blah

# %%
eval(code)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## Syntax etc.

# %%
def add(a, b):
    'Complex algorithm to add two numbers'
    return a+b

# %%
print(type(add))
# Out:
# <class 'function'>

# %%
add.__doc__
# Out:
# 'Complex algorithm to add two numbers'

# %%
help(add)
# Out:
# Help on function add in module __main__:
#
# add(a, b)
#     Complex algorithm to add two numbers

# %%
class Foo:
    'pointless class'

# %%
Foo.__doc__
# Out:
# 'pointless class'

# %%
help(Foo)
# Out:
# Help on class Foo in module __main__:
#
# class Foo(builtins.object)
#  |  pointless class
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# Was ist das mit ``__``?

# %%
class Bar:
    def __init__(self, param):
        self.member = param

# %%
b = Bar(42)

# %%
class Bar:
    def __init__(self, param):
        self.member = param
    def doSomething(self):
        return self.member**2

# %%
b = Bar(42)
b.doSomething()
# Out:
# 1764

# %%
print(b)
# Out:
# <__main__.Bar object at 0x7f5af9208fa0>

# %%
class Bar:
    def __init__(self, param):
        self.member = param
    def doSomething(self):
        return self.member**2
    def __str__(self):
        return f'Ein nettes sinnloses Objekt mit dem Wert {self.member}'

# %%
b = Bar(42)

# %%
print(b)
# Out:
# Ein nettes sinnloses Objekt mit dem Wert 42

# %% [markdown]
# ## Variables

# %%
a = 42

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a = 1.5

# %%
print(type(a))
# Out:
# <class 'float'>

# %%
a = 'blah'

# %%
print(type(a))
# Out:
# <class 'str'>

# %%
a = [1,2,3]
print(type(a))
# Out:
# <class 'list'>

# %% [markdown]
# **Tuple unpacking**

# %%
a = 1
b = 2

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
a, b = 1, 2

# %%
x = 1, 2

# %%
print(type(x))
# Out:
# <class 'tuple'>

# %%
x
# Out:
# (1, 2)

# %%
try:
    a, b, c = 1, 2
except Exception as e:
    print(e, type(e))
# Out:
# not enough values to unpack (expected 3, got 2) <class 'ValueError'>

# %%
print('hier bin ich')
# Out:
# hier bin ich

# %%
a, b
# Out:
# (1, 2)

# %%
tmp = a
a = b
b = tmp

# %%
a, b
# Out:
# (2, 1)

# %%
a, b = b, a

# %%
a, b
# Out:
# (1, 2)

# %% [markdown]
# **Object Identity**

# %%
a = 42

# %%
id(a)
# Out:
# 140028786083344

# %%
b = a

# %%
id(b)
# Out:
# 140028786083344

# %%
b = 7

# %%
id(b)
# Out:
# 140028786082224

# %%
id(a)
# Out:
# 140028786083344

# %% [markdown]
# ## Datatypes

# %%
i = 42

# %%
i = -42

# %%
i
# Out:
# -42

# %%
i = 0o644

# %%
i
# Out:
# 420

# %%
i = 0xdeadbeef

# %%
i
# Out:
# 3735928559

# %%
i = 0b01110101

# %%
i
# Out:
# 117

# %%
i = 2**64-1

# %%
bin(i)
# Out:
# '0b1111111111111111111111111111111111111111111111111111111111111111'

# %%
len(bin(i))
# Out:
# 66

# %%
i += 1

# %%
i
# Out:
# 18446744073709551616

# %%
len(bin(i))
# Out:
# 67

# %%
10**1000
# Out:
# ...

# %%
3/2
# Out:
# 1.5

# %%
3//2
# Out:
# 1

# %%
l1 = [1,2,3]
l2 = [2,3,4]
try:
    l1*l2
except Exception as e:
    print(e, type(e))
# Out:
# can't multiply sequence by non-int of type 'list' <class 'TypeError'>

# %%
l1 + l2
# Out:
# [1, 2, 3, 2, 3, 4]

# %% [markdown]
# ### Datatype Conversions

# %%
i = 42

# %%
s = str(i)

# %%
s
# Out:
# '42'

# %%
i.__str__()
# Out:
# '42'

# %%
i.__float__()
# Out:
# 42.0

# %%
f = float(i)

# %%
f
# Out:
# 42.0

# %%
int(f)
# Out:
# 42

# %%
f.__int__()
# Out:
# 42

# %%
s = '42'

# %%
int(s)
# Out:
# 42

# %%
int(s, 16)
# Out:
# 66

# %%
s = '0xdeadbeef'

# %%
try:
    int(s)
except Exception as e:
    print(e, type(e))
# Out:
# invalid literal for int() with base 10: '0xdeadbeef' <class 'ValueError'>

# %%
int(s, 16)
# Out:
# 3735928559

# %%
1 + 2.3
# Out:
# 3.3

# %%
try:
    '1' + 2
except Exception as e:
    print(e, type(e))
# Out:
# can only concatenate str (not "int") to str <class 'TypeError'>

# %%
try:
    '1'.__add__(2)
except Exception as e:
    print(e, type(e))
# Out:
# can only concatenate str (not "int") to str <class 'TypeError'>

# %% [markdown]
# Difference between ctor and ``eval()``?

# %%
int('42')
# Out:
# 42

# %%
eval('42')
# Out:
# 42

# %%
s = '[1,2,3]'

# %%
list(s)
# Out:
# ['[', '1', ',', '2', ',', '3', ']']

# %%
eval(s)
# Out:
# [1, 2, 3]

# %%
code = '''
i = 0
while i<42:
    i+=1
print(i)
'''

# %%
type(code)
# Out:
# str

# %%
exec(code)
# Out:
# 42

# %%
config = '''
SETTING_BLAH = 42
SETTING_FOO = 'jo oida'
'''

# %%
config_context = {}

# %%
exec(config, config_context)

# %%
config_context['SETTING_BLAH']
# Out:
# 42

# %% [markdown]
# ### Immutable vs. Mutable

# %%
def foo(a):
    print(id(a))

# %%
x = 666

# %%
id(x)
# Out:
# 140028703584464

# %%
foo(x)
# Out:
# 140028703584464

# %%
x = 42

# %%
id(x)
# Out:
# 140028786083344

# %%
x += 1

# %%
id(x)
# Out:
# 140028786083376

# %%
x = 42

# %%
id(x)
# Out:
# 140028786083344

# %%
x = 1234

# %%
y = 1234

# %%
x is y
# Out:
# False

# %%
id(x)
# Out:
# 140028703586608

# %%
id(y)
# Out:
# 140028703584944

# %% [markdown]
# **Memory Management**

# %%
abc = 666

# %%
del abc

# %%
try:
    abc
except Exception as e:
    print(e, type(e))
# Out:
# name 'abc' is not defined <class 'NameError'>

# %%
f = open('/etc/passwd')

# %%
f.close()

# %%
with open('/etc/passwd') as f:
    print(len(list(f)))
# Out:
# 48

# %% [markdown]
# ## Compound Datatypes

# %% [markdown]
# ### List, Tuple

# %%
l = [1,2,'drei']

# %%
len(l)
# Out:
# 3

# %%
l.append(4)

# %%
len(l)
# Out:
# 4

# %%
l
# Out:
# [1, 2, 'drei', 4]

# %%
l1 = [5, 'sechs']

# %%
l.extend(l1)

# %%
l
# Out:
# [1, 2, 'drei', 4, 5, 'sechs']

# %%
l.append(l1)

# %%
l
# Out:
# [1, 2, 'drei', 4, 5, 'sechs', [5, 'sechs']]

# %%
l.reverse()

# %%
l
# Out:
# [[5, 'sechs'], 'sechs', 5, 4, 'drei', 2, 1]

# %%
l += l1

# %%
l
# Out:
# [[5, 'sechs'], 'sechs', 5, 4, 'drei', 2, 1, 5, 'sechs']

# %%
t = (1,2,'drei')

# %%
try:
    t.append(4.0)
except Exception as e:
    print(e, type(e))
# Out:
# 'tuple' object has no attribute 'append' <class 'AttributeError'>

# %%
t1 = (5, 'sechs')

# %%
id(t)
# Out:
# 140028704065536

# %%
t += t1

# %%
id(t)
# Out:
# 140028705463872

# %% [markdown]
# **The `in`` operator**

# %%
l = [3,4,1,'fuenf']

# %%
3 in l
# Out:
# True

# %%
5 not in l
# Out:
# True

# %%
not 5 in l
# Out:
# True

# %%
'fuenf' in l
# Out:
# True

# %%
6 in l
# Out:
# False

# %% [markdown]
# ### Dictionary

# %%
d = {'one': 1, 'two': 2, 3: 'three'}

# %%
d['one']
# Out:
# 1

# %%
try:
    d['three']
except Exception as e:
    print(e, type(e))
# Out:
# 'three' <class 'KeyError'>

# %%
'three' in d
# Out:
# False

# %%
value = d.get('three')

# %%
print(value)
# Out:
# None

# %%
d['three'] = 3

# %%
'three' in d
# Out:
# True

# %%
del d['three']

# %%
'three' in d
# Out:
# False

# %%
d
# Out:
# {'one': 1, 'two': 2, 3: 'three'}

# %% [markdown]
# ### Set

# %%
s = {1,2,'drei'}

# %%
s.add(4.0)

# %%
s.remove('drei')

# %%
2 in s
# Out:
# True

# %%
l = [1,2,3]

# %%
s.add(l)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_48599/1125713270.py in <module>
# ----> 1 s.add(l)
#
# TypeError: unhashable type: 'list'

# %%
i = 42
i.__hash__()

# %%
i = 1234567876543234567654321234565432123456
i.__hash__()

# %%
s.add((1,2,3))

# %% [markdown]
# ## Slicing

# %%
l = [2,3,4,5,6]

# %%
l[2:4]

# %%
l[2:5]

# %%
l[2:len(l)]

# %%
l[2:len(l)-1]

# %%
l[2:-1]

# %%
l[1]

# %%
l[1]

# %%
l[0]
# Out:
# 1

# %%
try:
    l[len(l)]
except Exception as e:
    print(e, type(e))
# Out:
# list index out of range <class 'IndexError'>

# %%
l[len(l)-1]
# Out:
# 3

# %%
l[-1]
# Out:
# 3

# %%
l[0:6]
# Out:
# [1, 2, 3]

# %%
l[0:]
# Out:
# [1, 2, 3]

# %%
l[:]
# Out:
# [1, 2, 3]

# %%
l[1:]
# Out:
# [2, 3]

# %% [markdown]
# ## ``for``

# %%
for name in ['Caro', 'Johanna', 'Eva', 'Jörg']:
    print(name)
# Out:
# Caro
# Johanna
# Eva
# Jörg

# %%
l = [0,1,2,3,4]
for elem in l:
    print(elem)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for elem in range(5):
    print(elem)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
r = range(5)

# %%
print(type(r))
# Out:
# <class 'range'>

# %% [markdown]
# ### Iterator Protocol

# %%
r = range(3)

# %%
it = iter(r)

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
try:
    next(it)
except Exception as e:
    print(e, type(e))
# Out:
#  <class 'StopIteration'>

# %%
l = [0,1,2]

# %%
it = iter(l)

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
try:
    next(it)
except Exception as e:
    print(e, type(e))
# Out:
#  <class 'StopIteration'>

# %%
def my_range(n):
    current = 0
    yield current
    while current < n:
        yield current
        current += 1

# %%
r = my_range(3)

# %%
print(type(r))
# Out:
# <class 'generator'>

# %%
it = iter(r)

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 0

# %%
next(it)
# Out:
# 1

# %%
next(it)
# Out:
# 2

# %%
try:
    next(it)
except Exception as e:
    print(e, type(e))
# Out:
#  <class 'StopIteration'>

# %% [markdown]
# ## The ``range`` Function

# %%
for elem in range(3):
    print(elem)
# Out:
# 0
# 1
# 2

# %%
for elem in range(0,3):
    print(elem)
# Out:
# 0
# 1
# 2

# %%
for elem in range(1,4):
    print(elem)
# Out:
# 1
# 2
# 3

# %%
for elem in range(1,7,2):
    print(elem)
# Out:
# 1
# 3
# 5

# %%
list('abc')
# Out:
# ['a', 'b', 'c']

# %%
for elem in 'abc':
    print(elem)
# Out:
# a
# b
# c

# %%
for elem in range(3):
    print(elem)
# Out:
# 0
# 1
# 2

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
for elem in ['Joerg', 'Johanna', 'Caro', 'Philipp', 'Eva']:
    print(elem)
# Out:
# Joerg
# Johanna
# Caro
# Philipp
# Eva

# %%
i = 0
for elem in ['Joerg', 'Johanna', 'Caro', 'Philipp', 'Eva']:
    print(i, elem)
    i += 1
# Out:
# 0 Joerg
# 1 Johanna
# 2 Caro
# 3 Philipp
# 4 Eva

# %%
for elem in enumerate(['Joerg', 'Johanna', 'Caro', 'Philipp', 'Eva']):
    print(elem)
# Out:
# (0, 'Joerg')
# (1, 'Johanna')
# (2, 'Caro')
# (3, 'Philipp')
# (4, 'Eva')

# %%
for elem in enumerate(['Joerg', 'Johanna', 'Caro', 'Philipp', 'Eva']):
    pos = elem[0]
    name = elem[1]
    print(pos, name)
# Out:
# 0 Joerg
# 1 Johanna
# 2 Caro
# 3 Philipp
# 4 Eva

# %%
for pos, name in enumerate(['Joerg', 'Johanna', 'Caro', 'Philipp', 'Eva']):
    print(pos, name)
# Out:
# 0 Joerg
# 1 Johanna
# 2 Caro
# 3 Philipp
# 4 Eva

# %%
for pos, elem in enumerate(range(3, 7)):
    print(pos, elem)
# Out:
# 0 3
# 1 4
# 2 5
# 3 6

# %% [markdown]
# ## References, (Im)mutability

# %%
a = 42

# %%
b = a

# %%
id(a), id(b)
# Out:
# (140028786083344, 140028786083344)

# %%
a = 666

# %%
b
# Out:
# 42

# %%
id(a)
# Out:
# 140028685668272

# %%
id(b)
# Out:
# 140028786083344

# %%
l1 = [1,2,3]

# %%
l2 = l1

# %%
l2.append(4)

# %%
l2
# Out:
# [1, 2, 3, 4]

# %%
l1
# Out:
# [1, 2, 3, 4]

# %%
l1 = [1,2,3]
l2 = l1[:]

# %%
id(l1), id(l2)
# Out:
# (140028704379136, 140028703498368)

# %%
l1 = [1, ['a', 'b'], 2]

# %%
id(l1)
# Out:
# 140028685999936

# %%
l2 = l1[:]

# %%
id(l2)
# Out:
# 140028686257344

# %%
l1.append(3)

# %%
l1
# Out:
# [1, ['a', 'b'], 2, 3]

# %%
l2
# Out:
# [1, ['a', 'b'], 2]

# %%
l1[1]
# Out:
# ['a', 'b']

# %%
l2[1]
# Out:
# ['a', 'b']

# %%
l1[1].append('c')

# %%
l1
# Out:
# [1, ['a', 'b', 'c'], 2, 3]

# %%
l2
# Out:
# [1, ['a', 'b', 'c'], 2]

# %%
id(l1[1])
# Out:
# 140028686004416

# %%
id(l2[1])
# Out:
# 140028686004416

# %% [markdown]
# ## Functions

# %%
def foo(a):
    return a**2

# %%
print(type(foo))
# Out:
# <class 'function'>

# %%
x = foo

# %%
x(2)
# Out:
# 4

# %%
foo = 666

# %%
try:
    foo(2)
except Exception as e:
    print(e, type(e))
# Out:
# 'int' object is not callable <class 'TypeError'>

# %%
global_variable = 666

# %%
def bar():
    print(global_variable)

# %%
bar()
# Out:
# 666

# %%
def bar2():
    global_variable = 42

# %%
bar2()

# %%
global_variable
# Out:
# 666

# %%
def bar3():
    global global_variable
    global_variable = 42

# %%
bar3()

# %%
global_variable
# Out:
# 42

# %%
def bar4(param=42):
    print(param)

# %%
bar4(666)
# Out:
# 666

# %%
bar4()
# Out:
# 42

# %%
def bar5(param=[]):
    print(param)

# %%
bar5(42)
# Out:
# 42

# %%
bar5()
# Out:
# []

# %%
def bar6(param=[]):
    param.append(666)
    print(param)

# %%
bar6()
# Out:
# [666]

# %%
bar6()
# Out:
# [666, 666]

# %%
dir(bar6)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %%
bar6.__defaults__
# Out:
# ([666, 666],)

# %%
bar6()
# Out:
# [666, 666, 666]

# %%
bar6()
# Out:
# [666, 666, 666, 666]

# %%
bar6([42])
# Out:
# [42, 666]

# %%
bar6()
# Out:
# [666, 666, 666, 666, 666]

# %%
l = [42]
bar6(l)
# Out:
# [42, 666]

# %%
l
# Out:
# [42, 666]

# %% [markdown]
# **And ``yield``?**

# %%
def f():
    return 42
    return 666

# %%
f()
# Out:
# 42

# %%
type(f)
# Out:
# function

# %%
def f():
    yield 42
    yield 666

# %%
type(f)
# Out:
# function

# %%
f()
# Out:
# <generator object f at 0x7f5af81a3a00>

# %%
gen = f()

# %%
gen
# Out:
# <generator object f at 0x7f5af81a3ae0>

# %%
for i in gen:
    print(i)
# Out:
# 42
# 666

# %%
def f():
    print('start, yielding 42')
    yield 42
    print('after yield 42, yielding 666')
    yield 666
    print('after yield 666')

# %%
gen = f()
gen
# Out:
# <generator object f at 0x7f5af81a3c30>

# %%
for i in gen:
    print(i)
# Out:
# start, yielding 42
# 42
# after yield 42, yielding 666
# 666
# after yield 666

# %%
gen = f()

# %%
it = iter(gen)

# %%
next(it)
# Out:
# start, yielding 42
# 42

# %%
next(it)
# Out:
# after yield 42, yielding 666
# 666

# %%
try:
    next(it)
except Exception as e:
    print(e, type(e))
# Out:
# after yield 666
#  <class 'StopIteration'>
